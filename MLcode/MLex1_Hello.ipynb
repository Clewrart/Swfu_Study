# %%
print("你好，机器学习！")
# Out:
# 你好，机器学习！

# %%
# %%file D:/N01_CSTRecourse/m02_2025-2026-01/MLcode/ex1/jupyter/Example1.py
import tensorflow as tf 
print(tf.__version__)
# Out:
# Writing D:/N01_CSTRecourse/m02_2025-2026-01/MLcode/ex1/jupyter/Example1.py

# %%
# %run D:/N01_CSTRecourse/m02_2025-2026-01/MLcode/ex1/jupyter/Example1.py
# Out:
# 2.20.0

# %%
# %pwd
# Out:
# 'C:\\Users\\siyu_'
